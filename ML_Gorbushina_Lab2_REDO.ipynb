# %% [markdown]
# # №1
# ## (3 балла)
# Напишите программы, которые при помощи matplotlib выводят следующие графики ...

# %%
import matplotlib.pyplot as plt
import numpy as np

def graph1():
    plt.figure(figsize=(8, 6))
    x_axis = [x*10 for x in range(0, 6)]
    y_axis = [y*30 for y in range(0, 6)]
    
    plt.xlabel('x - axis')
    plt.ylabel('y - axis')
    plt.title('Draw a line')
    plt.plot(x_axis, y_axis, color='blue')
    plt.xlim(0, 50)
    plt.ylim(0, 160)
    plt.show()

def graph2():
    plt.figure(figsize=(8, 6))
    
    x_blue = np.array([10, 15, 20, 25, 30])
    y_blue = np.array([20, 30, 40, 25, 10])
    
    x_red = np.array([10, 15, 20, 25, 30])
    y_red = np.array([40, 25, 10, 20, 30])
    
    plt.title("Two or more lines with different widths and colors with suitable legends")
    plt.xlabel('x - axis')
    plt.ylabel('y - axis')
    plt.xlim(10, 30)
    plt.ylim(10, 40)
    plt.plot(x_blue, y_blue, color='blue', linewidth=3, label='line1-width-3')
    plt.plot(x_red, y_red, color='red', linewidth=5, label='line2-width-5')
    plt.legend()
    
    plt.show()

    
def graph3():
    plt.figure(figsize=(8, 6))
    
    x_blue = np.array([10, 15, 20, 25, 30])
    y_blue = np.array([20, 30, 40, 25, 10])
    
    x_red = np.array([10, 15, 20, 25, 30])
    y_red = np.array([40, 25, 10, 20, 30])
    
    plt.title("Plot with two or more lines with different styles")
    plt.xlabel('x - axis')
    plt.ylabel('y - axis')
    plt.xlim(10, 30)
    plt.ylim(10, 40)
    plt.plot(x_blue, y_blue, color='blue', linewidth=3, label='line1-dotted', linestyle=':')
    plt.plot(x_red, y_red, color='red', linewidth=5, label='line2-dashed', linestyle='--', dashes=(1, 1))
    plt.legend()
    
    plt.show()

def graph4():
    plt.figure(figsize=(8, 6))
    
    x = [1, 4, 5, 6, 7]
    y = [2, 6, 3, 6, 3]
    
    plt.title("Display marker")
    plt.xlabel('x - axis')
    plt.ylabel('y - axis')
    plt.xlim(1, 8)
    plt.ylim(1, 8)
    plt.plot(x, y, color='red', linewidth=2, linestyle='-.', dashes=(2, 1, 1, 1),
             marker='o', markerfacecolor='blue', markeredgecolor='blue', markersize=10)
    plt.show()
    

def graph5():
    plt.figure(figsize=(8, 6))
    
    x_blue = [2, 3, 5, 6, 8]
    y_blue = [1, 5, 10, 18, 20]
    
    x_red = [3, 4, 6, 7, 9]
    y_red = [3, 6, 11, 20, 22]
    
    plt.xlim(0, 10)
    plt.ylim(0, 30)
    plt.plot(x_red, y_red, linestyle='none', marker='o', color='red', markeredgecolor='black', markersize=6)
    plt.plot(x_blue, y_blue, linestyle='none', marker='*', color='blue', markersize=4)
    plt.show()
    

def graph6():
    dates_x = ['2016-10-03', '2016-10-04', '2016-10-05', '2016-10-06', '2016-10-07']
    y = [772.5, 776.4, 776.45, 776.85, 775.08]
    
    plt.figure(figsize=(8, 6))
    
    plt.title('Closing stock value of Alphabet Inc.')
    plt.xlabel('Date')
    plt.ylabel('Closing Value')
    plt.ylim(772.5, 777.0)
    plt.xlim()
    plt.plot(dates_x, y, 'o-', markersize=6, linewidth=2,
             color='red', markerfacecolor='red', markeredgecolor='black')
    plt.grid(True, which='major', alpha=0.5, linestyle='-', linewidth=0.8, color='red')
    plt.grid(True, which='minor', alpha=0.2, linestyle='-.', linewidth=0.5, color='gray')
    plt.minorticks_on()

    plt.show()

graph1()
graph2()
graph3()
graph4()
graph5()
graph6()

# %% [markdown]
# # №2
# ## (4 балла)
# Создайте рисунок с основными элементами изображения, похожий на приведенный ниже. Элементы изображения обозначены кругами и подписаны синим шрифтом. Допускается изменение линий, цвета, толщины линий и т.п., главное, чтобы все обозначенные элементы присутствовали.

# %%
plt.figure(figsize=(8, 8))

x = np.linspace(0, 4, 100)
y1 = np.interp(np.linspace(0, 4, 100), [0, 0.57, 1.14, 1.71, 2.29, 2.86, 3.43, 4], 
               [3.80, 3.5, 3.25, 3, 2.5, 2.25, 2, 2.15])
y2 = np.interp(np.linspace(0, 4, 100), [0, 0.67, 1.33, 2, 2.67, 3.33, 4], 
               [1, 0.75, 0.5, 0.75, 1, 1.25, 1.40])

plt.plot(x, y1, 'b-', linewidth=2, label='Синяя линия')
plt.plot(x, y2, 'r-', linewidth=2, label='Красная линия')

np.random.seed(13)
x_scatter = np.linspace(0.25, 3.5, 30)
y_scatter = np.random.uniform(1.5, 2.5, len(x_scatter))
plt.scatter(x_scatter, y_scatter, color='white', edgecolors='black', marker='o', s=50, zorder=5)

plt.xlabel('Подпись оси OX')
plt.ylabel('Подпись оси OY')

plt.gca().yaxis.set_major_locator(plt.MultipleLocator(1.0))
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(0.25))

plt.gca().xaxis.set_major_locator(plt.MultipleLocator(1.0))
plt.gca().xaxis.set_minor_locator(plt.MultipleLocator(0.25))
plt.gca().xaxis.set_minor_formatter(plt.FormatStrFormatter('%.2f'))

plt.grid(True, which='major', linestyle='-', alpha=0.7)
plt.grid(True, which='minor', linestyle='--', alpha=0.4)

plt.title('Элементы изображения')
plt.legend()

plt.xlim(0, 4)
plt.ylim(0, 4)

plt.show()

# %% [markdown]
# # №3
# ## 2 балла
# Постройте график функции
# y(x) = x*x - x - 6
# и по графику найдите корни уравнения y(x) = 0.
# (Не нужно применять численных методов — просто так подберите отображение, чтобы на графике были видны корни функции.)

# %%
# корни 3, -2

def task_3():
    x = np.linspace(-3, 5, 100)
    y = x**2 - x - 6

    plt.figure(figsize=(10, 6))
    plt.plot(x, y, color='black', linewidth=2)
    plt.grid(True, alpha=0.25, linestyle='-.', linewidth=1, )

    plt.show()
    
task_3()

# %% [markdown]
# # №4
# ## 2 балла
# Постройте график функции
#
# что-то там логарифм экспонента ляляля

# %%
def func(x):
    base = 1 + np.tan(1 / (1 + np.sin(x) ** 2))
    value = (x**2 + 1) * np.exp(-np.abs(x) / 10)
    
    result = np.log(value) / np.log(base)
    
    result[(base <= 0) | (base == 1)] = np.nan
    
    return result
        
x = np.linspace(-10, 10, 1000)
y = func(x)
  
plt.figure(figsize=(12, 6))
plt.plot(x, y, 'b-', linewidth=2)
plt.grid(True, alpha=0.3)
plt.ylim(-2, 11)
plt.xlim(-11, 11)

plt.show()

# %% [markdown]
# # №5
# ## 4 балла
# Напишите программы, которые при помощи matplotlib выводят следующие диаграммы: ...

# %%
def graph5_1():
    languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22, 17.6, 8.8, 8, 7.7, 6.7]

    plt.figure(figsize=(10, 8))

    x_positions = [2, 7, 12, 17, 22, 27]
    
    plt.bar(x_positions, popularity, color="blue",
                edgecolor='black', linewidth=1, width=4) 
    
    plt.xlabel('Languages', fontsize=12, labelpad=10)
    plt.ylabel('Popularity', fontsize=12, labelpad=10)
    plt.title('Popularity of Programming Language Worldwide, Oct 2017 compared to a year ago', 
                fontsize=14, pad=20)

    plt.grid(which='major', color="red", linestyle='-', linewidth=1, alpha=0.7)
    plt.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.4)

    plt.yticks(np.arange(0, 26, 5))
    plt.gca().set_yticks(np.arange(0, 26, 1), minor=True)
    
    plt.gca().set_xticks(np.arange(0, 31, 5))
    plt.gca().set_xticks(np.arange(0, 31, 1), minor=True)
    
    plt.gca().tick_params(which='minor', length=0)
    
    plt.xticks(np.linspace(0, 25, 6), languages)

    plt.ylim(0, 25)
    plt.xlim(0, 30)

    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

    plt.show()
    
def graph5_2():
    languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22, 17.6, 8.8, 8, 7.7, 6.7]

    plt.figure(figsize=(10, 8))

    y_positions = [2, 7, 12, 17, 22, 27]
    
    plt.barh(y_positions, popularity, color="green",
                   edgecolor='black', linewidth=1, height=4)
    
    plt.ylabel('Languages', fontsize=12, labelpad=10)
    plt.xlabel('Popularity', fontsize=12, labelpad=10)
    plt.title('Popularity of Programming Language Worldwide, Oct 2017 compared to a year ago', 
             fontsize=14, pad=20)

    plt.grid(which='major', color="red", linestyle='-', linewidth=1, alpha=0.7)
    plt.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.4)

    plt.xticks(np.arange(0, 26, 5))
    plt.gca().set_xticks(np.arange(0, 26, 1), minor=True)
    
    plt.gca().set_yticks(np.arange(0, 31, 5))
    plt.gca().set_yticks(np.arange(0, 31, 1), minor=True)
    
    plt.yticks(np.linspace(0, 25, 6), languages)

    plt.gca().tick_params(which='minor', length=0)

    plt.xlim(0, 25)
    plt.ylim(0, 30)

    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

    plt.show()

def graph5_3():
    languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22, 17.6, 8.8, 8, 7.7, 6.7]

    plt.figure(figsize=(10, 8))

    x_positions = [2, 7, 12, 17, 22, 27]
    colors = ['red', 'black', 'green', 'blue', 'yellow', 'cyan']
    
    plt.bar(x_positions, popularity, color=colors,
                edgecolor='black', linewidth=1, width=4) 
    
    plt.xlabel('Languages', fontsize=12, labelpad=10)
    plt.ylabel('Popularity', fontsize=12, labelpad=10)
    plt.title('Popularity of Programming Language Worldwide, Oct 2017 compared to a year ago', 
                fontsize=14, pad=20)

    plt.grid(which='major', color="red", linestyle='-', linewidth=1, alpha=0.7)
    plt.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.4)

    plt.yticks(np.arange(0, 26, 5))
    plt.gca().set_yticks(np.arange(0, 26, 1), minor=True)
    
    plt.gca().set_xticks(np.arange(0, 31, 5))
    plt.gca().set_xticks(np.arange(0, 31, 1), minor=True)
    
    plt.gca().tick_params(which='minor', length=0)
    
    plt.xticks(np.linspace(0, 25, 6), languages)

    plt.ylim(0, 25)
    plt.xlim(0, 30)

    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

    plt.show()
    
def graph5_4():
    languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22, 17.6, 8.8, 8, 7.7, 6.7]

    plt.figure(figsize=(10, 8))

    x_positions = [2, 7, 12, 17, 22, 27]
    
    bars = plt.bar(x_positions, popularity, color="blue",
                edgecolor='black', linewidth=1, width=4) 
    
    plt.xlabel('Languages', fontsize=12, labelpad=10)
    plt.ylabel('Popularity', fontsize=12, labelpad=10)
    plt.title('Popularity of Programming Language Worldwide, Oct 2017 compared to a year ago', 
                fontsize=14, pad=20)

    plt.grid(which='major', color="red", linestyle='-', linewidth=1, alpha=0.7)
    plt.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.4)

    plt.yticks(np.arange(0, 26, 5))
    plt.gca().set_yticks(np.arange(0, 26, 1), minor=True)
    
    plt.gca().set_xticks(np.arange(0, 31, 5))
    plt.gca().set_xticks(np.arange(0, 31, 1), minor=True)
    
    plt.gca().tick_params(which='minor', length=0)
    
    plt.xticks(np.linspace(0, 25, 6), languages)

    plt.ylim(0, 25)
    plt.xlim(0, 30)

    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 0.1,
                f'{height:.6f}', ha='center', va='bottom', fontsize=10)
    plt.show()
    
def graph5_5():
    languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    popularity = [22, 17.8, 8.85, 7.9, 7.8, 6.8]

    plt.figure(figsize=(10, 8))

    x_positions = [0.25, 5.5, 11, 17.25, 20.5, 25.75]
    widths = [0.5, 1, 2, 4.5, 1, 1.5]
    
    plt.bar(x_positions, popularity, color="blue",
                edgecolor='black', linewidth=1, width=widths) 
    
    plt.xlabel('Languages', fontsize=12, labelpad=10)
    plt.ylabel('Popularity', fontsize=12, labelpad=10)
    plt.title('Popularity of Programming Language Worldwide, Oct 2017 compared to a year ago', 
                fontsize=14, pad=20)

    plt.grid(which='major', color="red", linestyle='-', linewidth=1, alpha=0.7)
    plt.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.7)

    plt.yticks(np.arange(0, 26, 5))
    plt.gca().set_yticks(np.arange(0, 26, 1), minor=True)
    
    plt.gca().set_xticks(np.arange(0, 31, 5))
    plt.gca().set_xticks(np.arange(0, 31, 1), minor=True)
    
    plt.gca().tick_params(which='minor', length=0)
    
    plt.xticks(np.linspace(0, 25, 6), languages)

    plt.ylim(0, 25)
    plt.xlim(0, 30)

    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

    plt.show()
    
def graph5_6():
    persons = ['G1', 'G2', 'G3', 'G4', 'G5']
    men_scores = [22, 30, 33, 30, 26]
    women_scores = [25, 32, 30, 35, 29]

    plt.figure(figsize=(10, 8))

    x_positions = np.array([2, 7, 12, 17, 22])
    bar_width = 1.5

    plt.bar(x_positions - bar_width/2, men_scores, 
                      color='green', edgecolor='black', linewidth=1, 
                      width=bar_width, label='Men')

    plt.bar(x_positions + bar_width/2, women_scores, 
                        color='red', edgecolor='black', linewidth=1, 
                        width=bar_width, label='Women')

    plt.xlabel('Person', fontsize=12, labelpad=10)
    plt.ylabel('Score', fontsize=12, labelpad=10)
    plt.title('Scores by person', fontsize=14, pad=20)

    plt.yticks(np.arange(0, 36, 5))
    plt.gca().set_yticks(np.arange(0, 36, 1), minor=True)
 
    plt.gca().set_xticks(np.arange(0, 26, 5))
    plt.gca().set_xticks(np.arange(0, 26, 1), minor=True)

    plt.gca().tick_params(which='minor', length=0)
    plt.gca().tick_params(axis='y', direction='in', which='both', 
                   left=True, right=True, labelleft=True, labelright=False)

    plt.gca().tick_params(axis='x', direction='in', which='major',
                   bottom=False, top=True, labelbottom=True, labeltop=False)

    plt.xticks(x_positions, persons)

    plt.ylim(0, 35)
    plt.xlim(0, 25)

    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

    plt.legend(fontsize=14)

    plt.show()
    
def graph5_7():
    languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    percentages = [31.3, 24.8, 12.4, 11.3, 10.8, 9.4]
    colors = ["#5C8FDB", "#F39548", "#60C265", "#DA4646", "#BD73BD", "#8F695A"]
    
    plt.figure(figsize=(10, 8))
    
    java_explode = (0.1, 0, 0, 0, 0, 0)
    contour = {'edgecolor': 'black'}
    
    plt.pie(
        percentages, labels=languages, colors=colors,
        autopct='%1.1f%%', startangle=140, explode=java_explode,
        shadow=True, wedgeprops=contour)

    plt.show()
    
def graph5_8():
    languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
    percentages = [31.3, 24.8, 12.4, 11.3, 10.8, 9.4]
    colors = ["#5C8FDB", "#F39548", "#60C265", "#DA4646", "#BD73BD", "#8F695A"]
    
    plt.figure(figsize=(10, 8))
    
    java_explode = (0.1, 0, 0, 0, 0, 0.1)
    contour = {'edgecolor': 'black'}
    
    plt.pie(
        percentages, labels=languages, colors=colors,
        autopct='%1.1f%%', startangle=140, explode=java_explode,
        shadow=True, wedgeprops=contour)

    plt.title('Popularity of Programming Language Worldwide, Oct 2017 compared to a year ago', 
          pad=10,
          bbox=dict(facecolor="#ADADAD", edgecolor='black', boxstyle='round,pad=0.5'))
    plt.show()

graph5_1()
graph5_2()
graph5_3()
graph5_4()
graph5_5()
graph5_6()
graph5_7()
graph5_8()

# %% [markdown]
# # №6
# ## 3 балла
# Напишите программы, которые при помощи matplotlib выводят следующие рисунки: ...

# %% [markdown]
# простите, `skip`
